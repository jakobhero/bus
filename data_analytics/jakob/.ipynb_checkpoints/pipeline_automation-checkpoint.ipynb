# %%
from sqlalchemy import create_engine
from config import config

# %%
engine=create_engine("postgresql://postgres:super_pw@localhost/postgres")

# %%
sql="SELECT DISTINCT line_id FROM trips"

# %%
with engine.connect() as connection:
    lines=connection.execute(sql)

# %%
unique_lines=[]
for row in lines:
    unique_lines.append(row['line_id'])
# Out:
# 75
# 68X
# 13
# 41A
# 46E
# 104
# 7A
# 18
# 32
# 25A
# 38A
# 76
# 33B
# 14C
# 37
# 33E
# 4
# 9
# 70D
# 56A
# 15B
# 65B
# 140
# 67X
# 68A
# 66
# 33X
# 61
# 11
# 31
# 114
# 43
# 41D
# 130
# 51X
# 49
# 69
# 41X
# 7
# 15
# 122
# 40
# 31D
# 27A
# 40D
# 111
# 25D
# 116
# 54A
# 145
# 7D
# 76A
# 17
# 15A
# 38B
# 120
# 185
# 45A
# 83A
# 25B
# 38D
# 63
# 84
# 17A
# 16D
# 70
# 15D
# 41B
# 32X
# 84X
# 39
# 25
# 14
# 31B
# 79
# 77A
# 66X
# 33A
# 31A
# 38
# 84A
# 238
# 68
# 236
# 16C
# 220
# 161
# 27X
# 46A
# 33
# 102
# 41C
# 53
# 27
# 151
# 66B
# 42
# 67
# 142
# 40E
# 47
# 150
# 270
# 44B
# 65
# 40B
# 44
# 239
# 59
# 7B
# 79A
# 77X
# 33D
# 184
# 39X
# 1
# 51D
# 42D
# 29A
# 83
# 69X
# 41
# 39A
# 27B
# 66A
# 16
# 25X
# 26
# 118
# 123
